# %% [markdown]
# <a href="https://colab.research.google.com/github/Ohjaun/2021_PNUAC_AIData/blob/main/07_codelab3_bs_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🏷️ **웹 동작원리**
#
#
# ---
# <img src ='https://drive.google.com/uc?export=view&id=1amZ78fUnfp3o5Q1XVKDG3eAAzKaYlPrp'>
#
# ---

# %% [markdown]
# # Beautiful Soup 모듈
# + HTML 및 XML 문서 를 구문 분석하기 위한 Python 패키지
# + DOM 추출
# + 기본적으로 UTF-8 인코딩 방식이지만 CP949도 지원

# %% [markdown]
# 🏷️ **웹 스크래핑(Web Scraping)과 웹 크롤링(Web Crawling)**
#
#
# ---
# + 웹 스크래핑(Web Scraping) : 웹 사이트 상에서 원하는 정보를 추출하는 기술
# + 웹 크롤링(Web Crawling) : 웹 크롤러(자동화봇)가정해진 규칙에 따라 웹 페이지를 수집해서 각 사이트의 정보를 분류하는 기술
#
#
#
#
# ---

# %% [markdown]
# ## BeautifulSoup 모듈을 활용한 스크래핑

# %% [markdown]
# ### 1. 웹 페이지 가져오기

# %%
#모듈 import 
from urllib.request import urlopen

url = 'https://news.daum.net/ranking/popular'
#웹 페이지 가져오기 
webpage = urlopen(url).read().decode('utf-8')
webpage[:200]
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />'

# %% [markdown]
# ### 2. BeautifulSoup 객체 생성
#
# ```python
# from bs4 import BeautifulSoup as bs
#
# 인스턴스명 = BeautifulSoup(markup, parser)
# ```
# * 첫 번째 인자 : HTML 형식의 문자열
# * 두 번째 인자 : 첫 번째 인자의 문자열을 해석하기 위한 파서
#
#   * **파서(parser) 종류**
#     + html.parser : 파이썬 표준 라이브러리에 포함된 파서로 빠르지만 유연하지 않기 때문에 단순한 HTML문서에 사용
#
#         ```
#         BeautifulSoup(markup, "html.parser")
#         ```
#
#     + lxml : 매우 빠르고 유연하지만 외부 의존
#       - lxml의 HTML 파서
#           ```
#           BeautifulSoup(markup, "lxml")
#           ```
#       - lxml의 XML 파서
#           ```
#           BeautifulSoup(markup, "lxml-xml")
#           ```
#
#     + html5lib : 웹 브라우저와 동일한 방식으로 페이지 구문 분석하는 파서로 매우 느리지만 매우 유연하지만 외부 의존
#         ```
#         BeautifulSoup(markup, "html5lib")
#       ```

# %%
#모듈 import 
from bs4 import BeautifulSoup as bs
#DOM 문서 만들기
html = bs(webpage, 'html.parser')

# %%
type(html)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 2. **Beautiful Soup 파싱 메소드**
# + 태그명
#   + **.find(태그명)** : 조건에 맞는 태그 1개만 찾음
#   + **.find_all(태그명)** : 조건에 맞는 모든 태그 찾음
# + css선택자
#   + **.select_one(선택자)** : 조건에 맞는 CSS선택자 1개만 찾음
#   + **.select(선택자)** : 조건에 맞는 CSS선택자 찾음

# %% [markdown]
# 🏷️ **HTML과 CSS**
#
#
# ---
#
#
#
# + **HTML(Hyper Text Markup Language)**
#   + 웹페이지 상에서 문단, 제목, 표, 이미지, 동영상 등을 정의하고 웹페이지 내용을 구조화하고 의미를 부여하는 마크업 언어
# + **CSS(Cascading Style Sheet)**
#   + 색상, 레이아웃 및 글꼴등 웹페이지의 디자인 요소를 담당하는 선언형 언어로 스타일 시트(Style Sheet)라고도 하고, HTML로 작성된 웹페이지를 보기 좋게 꾸며주는 스타일 규칙 언어
#
# + 참고 사이트 : <https://www.w3schools.com/>
#
#
# ---

# %% [markdown]
# #mArticle > div.rank_news > ul.list_news2 > li

# %%
#자료 추출하기
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
print(type(lis), ' 요소 수 : ', len(lis))
print(lis[0])
# Out:
# <class 'list'>  요소 수 :  50
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num rank_popular">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# </div>
# <a class="link_thumb" href="https://v.daum.net/v/20210709110028500">
# <img alt='尹측, 김건희 논문 논란에 "그럼 이재명 정세균 추미애는?"' aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F09%2Fyonhap%2F20210709110230586gmxx.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://v.daum.net/v/20210709110028500">尹측, 김건희 논문 논란에 "그럼 이재명 정세균 추미애는?"</a>
# <span class="info_news">연합뉴스</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         (서울=연합뉴스) 류미나 기자 = 윤석열 전 검찰총장 측은 8일 이재명 정세균 추미애 등 더불어민주당 대선 경선 후보의 논문 표절 의혹에 대한 해명을 공개 요구했다. ...
#                     </span>
# </div>
# </div>
# </li>

# %%
#필요한 자료 만들기
for li in lis:
  title = li.select_one('.cont_thumb > .tit_thumb > a').text.replace('"','')
  print(title)
# Out:
# 尹측, 김건희 논문 논란에 그럼 이재명 정세균 추미애는?
# 김부선, '가운뎃손가락' 들고 이재명씨 쪽팔리지 않으세요?
# 아무도 못오는 결혼식 됐다..예비 부부들 '4단계 격상' 울분
# [현장연결] 유은혜 서울·경기·인천 유초중고, 14∼25일 전면 원격수업
# 캐나다 호수 부근서 발견된 다이아몬드가 말했다..27억년 전 지구도 살만 했다고
# 日스가, 참을수 없는 동문서답..코로나 책임질거냐 묻자 백신을
# [사진 톡톡] 인도네시아 코로나 사망자 폭증에..
# 수도권 거리두기 4단계 격상..12일부터 2주간
# 1타강사 주예지, 전속 계약 위반으로 메가스터디에 8억여원 배상 판결
# 아이티 대통령 암살범 콜롬비아인 26명·미국인 2명 구성
# 현대百만 하루 8830건..확진자 폭증에 선별검사소 '번아웃'
# 국민의힘 32%, 4년9개월 만에 민주당 추월..국정농단 후 최고
# 푸대접에도 日 가려는 文 절박함..성과없이 체면 구길 수도
# 검찰 정진웅, 피해자 고통 호소를 오버액션으로 치부 징역 1년 구형(종합)
# 월요일 저녁 6시부터 '셧다운'..결국 '강제 스톱'되는 일상
# [단독][윤석열 인터뷰]⑤ 장모 일은 장모 일, 내 길과 달라..집사람, 새벽까지 공부하며 바빠
# 강남 뒤흔든 '코로나 패닉'..이웃끼리 인사도 안해요
# 여신도 길들이기 성폭력 30대 목사 징역 7년..법정구속(종합)
# [단독][윤석열 인터뷰]④ '윤석열 사단'이 '하나회'처럼 군림 한다고요..추 장관이 검찰에 대해 뭘 압니까
# 오세훈의 세월호 지우기..광화문 '기억공간' 철거 통보
# 조두순보다 더한 놈이 온다..'소녀 11명 성폭행' 김근식, 9월 출소
# [Q&A] '18시 이후 2인만' 제사·상견례도 예외없어..골프는 이번에도 캐디 '제외'
# 수도권 오후 6시 '통금'..백화점·마트 주말부터 걱정
# 與 윤로남불 尹 결혼 전 일..대선 전초전 '김건희 논문'
# 김기현 문대통령, 수사대상 박영수에 면직선물..은혜 갚나
# 재택 끝, 사표 행렬 막자..MS, 전 직원 1500달러 위로금
# 이재명 '대세론 굳히기' 실패.. 이낙연, 국민면접으로 '반등 기회'
# [Q&A] 4명 카페갔다 오후 6시 넘으면?..규정위반, 개인과태료 10만원
# 마지막 방역카드까지 썼다..1주 뒤 효과 안나오면 결국 '백신'
# 마약단속중!..'아이티 대통령 피살 당시 영상' SNS 공개
# 차라리 전국 셧다운해야..존페 위기 카페업계 '울분'
# '독직폭행 혐의' 정진웅, 실형 구형..한동훈이 자초해(종합)
# '4단계' 놀란 文대통령, 12일 오세훈·이재명·박남춘과 회의(상보)
# 윤석열 조국 의혹 쏟아질 때 대통령 임명장 잉크 만지며 고민
# 외신, 한국 거리두기 격상 긴급 보도..방역 모범국의 후퇴
# 셧다운 전에 '벙개' 쳤어요.. 다닥다닥 '서울의 밤'
# 화이자 백신접종 6개월 후 효과 감소..3차접종 허가요청
# 강남에선 3시간 줄서야 검사대란에..오세훈 불편 줄일 앱 개발 지시
# '노출방송 거부' 여직원 살해 BJ, 징역30년..극심한 고통
# 거리두기 4단계선 동거가족 모임만 허용..직계가족 안돼
# 홍대·강남 '데이트 커플'이 태반인데..2人은 상징적 숫자로 이해해야
# '만취' 포르쉐, 인도 돌진..신호등·차량 들이박아
# '전국 최다 확진' 서울시..오세훈 시장 대책에 역학조사 강화는 없어
# 집사람 술 싫어해..새벽까지 공부 윤석열, 쥴리설·논문 의혹 반박
# [뉴시스Pic] '가족들만 참석한 고(故) 박원순 전 시장 1주기 추모제'
# 기초단체장들 재난지원금, 선별없이 전 국민에 전액 국비로 지급해야
# 결혼식 되나요? 가족끼리 외식은?..거리두기 4단계 Q&A
# 이재명 '아웃사이더', 이낙연 '文후계자', 윤석열 '野 기수'
# 보험만기환급금을 압류당했어요 14만 원 주민세 체납했더니..
# '노출방송 거부' 여직원 무참히 살해한 BJ, 항소심서 감형 왜?

# %% [markdown]
# ## 해결문제
# ---
# 댓글많은 뉴스를 사이트의 제목을 수집해서 AI Cloud의 무료 AI 서비스 중 텍스트 감정 분석 결과를 분석하고 결과를 파일로 저장하시오.단, 감성분석 분석(긍정,중립,부정)은 함수를 이용하여 작성하고 댓글수와 제목의 쉼표는 제거하시오.
#
# 예시)
# news.csv 내용
# ```
# 순위,제목,댓글수,언론사,감성,신뢰도
# 1,故손정민 父 "서울경찰청 정민이와 나를 미워한다",2564,데일리안,부정,0.9970703125
# 2,신고만하면 한국인? "中에 나라 파냐" 국적법 때린 반중정서,2274,중앙일보,부정,0.99755859375
# 3,'잔여 백신' 첫날 젊은층 대거 몰렸다..AZ 부정적 시선 바뀌나,1726,파이낸셜뉴스,부정,0.98974609375
# 4,'도쿄올림픽 지도서 독도 삭제' 요구에 日정부 "수용 불가",1543,연합뉴스,부정,0.9873046875
#
# ...
#
# 47,"손정민 사건 제가 책임지고"..경찰 '김창룡 청장 가짜뉴스' 내사,115,뉴스1,부정,0.9921875
# 48,로또 1등 수령자에 통장 비번 요구·5억 적금 강매한 농협,105,뉴스1,부정,0.99072265625
# 49,'도쿄올림픽 지도서 독도 삭제' 韓요구에 日정부 "수용 불가",97,중앙일보,부정,0.986328125
# 50,올림픽 취소로 日 배상금 떠안나..日언론 "IOC와 불평등 계약",93,뉴스1,부정,0.99609375
#
# ```

# %%
from urllib.request import urlopen
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
import json

# %%
def getPage(url):
  webpage = urlopen(url).read().decode('utf-8')
  return webpage

# %%
def AiCloud(msg) :
 url = "http://svc.saltlux.ai:31781"
 headers={"Content-Type":"application/json" } 

 apiKey = "c25ba39e-8375-4c85-a9ed-dd0a27a3972f"
 rqData = {
    "key": apiKey,
    "serviceId": "11987300804",
    "argument": {
        "type": "0",
        "query": msg
    }
 }
 # 요청 객체 생성
 req = Request(url, headers=headers)

 # 전달 데이터 json 형태로 만들기
 jdata = json.dumps(rqData).encode('utf-8')

 #요청
 response = urlopen(req, jdata)

 # 요청에 대한 응답처리
 resp = response.read().decode('utf-8')
 resp = json.loads(resp)
 label = resp['label']
 score = resp['score']

 # 응답처리 반환
 return label, score

# %%
url = 'https://news.daum.net/ranking/bestreply'

wp = getPage(url)
wp
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="뉴스 랭킹"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<meta property="og:url" content="https://news.daum.net/ranking/bestreply" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>뉴스 랭킹 | 다음뉴스</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/news.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/calendar.css.merged.css" />\n\n<!--[if lte IE 8]>\n<script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>\n<![endif]-->\n<!--[if lt IE 9]>\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5dbfb0e/ie8.css.merged.css" />\n<![endif]-->\n\n<script src="//t1.daumcdn.net/media/kraken/news/5dbfb0e/common.merged.js"></script>\n\n<script type="text/javascript" src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>\n\n<script>\n  var ENV = {\n    Profile: {\n      isProduction: \'true\' || false,\n      isSandbox: \'\' || false,\n      isCbt: \'\' || false,\n    }\n  }\n</script>\n        <script src="//t1.daumcdn.net/media/kraken/news/5dbfb0e/rankingMain.merged.js"></script>\n</head>\n<body class="bg_news">\n<div id="kakaoIndex">\n    <a href="#kakaoBody">본문 바로가기</a>\n    <a href="#kakaoGnb">메뉴 바로가기</a>\n</div>\n\n<div id="kakaoWrap" class="news_type1">\n<div id="wrapMinidaum"></div>\n<script type="text/javascript">\n\tvar minidaum_options = {\n\t\tbgType\t\t\t\t: "white",\n\t\tenableLogoutRetun\t: true,\n\t\tdisableTracker\t\t: true, // false일 경우 사용, true일 경우 미사용\n\t\tenableShield\t\t: false\n\t};\n</script>\n<script src="https://go.daum.net/minidaum_pc.daum"></script>\n\n<div id="kakaoHead" role="banner">\n\t<div class="head_media">\n\t\t<h1>\n\t\t\t<a href="https://news.daum.net/" id="kakaoServiceLogo" data-tiara-layer="GNB default service_news"><span class="ir_wa">뉴스</span></a>\n\t\t</h1>\n\t\t<strong class="screen_out">관련서비스</strong>\n\t\t<ul id="kakaoRelServices" data-tiara-layer="GNB default">\n\t\t\t<li><a href="https://entertain.daum.net" class="link_services link_services1" data-tiara-layer="service_enter"><span class="ir_wa">연예</span></a></li>\n\t\t\t<li><a href="https://sports.daum.net" class="link_services link_services2" data-tiara-layer="service_sports"><span class="ir_wa">스포츠</span></a></li>\n\t\t</ul>\n<h2 class="screen_out">검색</h2>\n<div class="search_news" id="search_news">\n\t<form id="kakaoSearch" name="kakaoSearch" action="//search.daum.net/search" method="get">\n\t\t<fieldset class="fld_inside">\n\t\t\t<legend class="screen_out">검색어 입력폼</legend>\n\t\t\t<div class="box_searchbar">\n\t\t\t\t<label for="qVal" class="lab_search">통합검색</label>\n\t\t\t\t<input type="hidden" name="DA" value="23A" />\n\t\t\t\t<input type="hidden" name="rtmaxcoll" value="NNS">\n\t\t\t\t<input type="text" class="tf_keyword" id="qVal" name="q" value="" title="검색어 입력" autocomplete="off" spellcheck="false">\n\t\t\t\t<button id="kakaoBtnSearch" class="btn_search" type="submit"><span class="ir_wa">검색</span></button>\n\t\t\t</div>\n\t\t</fieldset>\n\t\t<div id="wrap_suggestBox" class="wrap_suggestBox">\n\t\t\t<div id="suggestBox" class="suggestBox box_sub">\n\t\t\t\t<div class="baseBox bg" style="display: none"></div>\n\t\t\t</div>\n\t\t</div>\n\t</form>\n</div>\n<script type="text/javascript" src="https://search1.daumcdn.net/search/suggest_pc/ ...

# %%
html = bs(wp, 'html.parser')

# %%
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
lis[0]
# Out:
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num ">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# <span class="info_rank">
# <span class="screen_out">댓글수</span>
# <span class="ico_news2">9,183</span>
# </span>
# </div>
# <a class="link_thumb" href="https://news.v.daum.net/v/20210709110028500">
# <img alt='尹측, 김건희 논문 논란에 "그럼 이재명 정세균 추미애는?"' aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F09%2Fyonhap%2F20210709110230586gmxx.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://news.v.daum.net/v/20210709110028500">尹측, 김건희 논문 논란에 "그럼 이재명 정세균 추미애는?"</a>
# <span class="info_news">연합뉴스</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         (서울=연합뉴스) 류미나 기자 = 윤석열 전 검찰총장 측은 8일 이재명 정세균 추미애 등 더불어민주당 대선 경선 후보의 논문 표절 의혹에 대한 해명을 공개 요구했다. ...
#                     </span>
# </div>
# </div>
# </li>

# %%
lis[0].select_one('.screen_out').text
# Out:
# '1'

# %%
lis[0].select_one('.ico_news2').text.replace(',','')
# Out:
# '9183'

# %%
lis[0].select_one('.tit_thumb > a').text
# Out:
# '尹측, 김건희 논문 논란에 "그럼 이재명 정세균 추미애는?"'

# %%
lis[0].select_one('.info_news').text
# Out:
# '연합뉴스'

# %%
with open('/content/sample_data/california_housing_test.csv', 'w') as fp :
  linehead = '순위,제목,댓글수,언론사,감성,신뢰도\n'
  fp.write(linehead)
  for li in lis :
    rank = li.select_one('.screen_out').text
    title = li.select_one('.tit_thumb > a').text.replace(',','')
    cnt = li.select_one('.ico_news2').text.replace(',','')
    news = li.select_one('.info_news').text
    aicloud = AiCloud(title)
    #aicloud = ('부정', '0.9')
    line = f'{rank},{title},{cnt},{news},{aicloud[0]},{aicloud[1]}\n'

    print(line)
    fp.write(line)
# Out:
# 1,尹측 김건희 논문 논란에 "그럼 이재명 정세균 추미애는?",9183,연합뉴스,부정,0.89697265625
#
# 2,이준석 "통일부도 없애자"..여가부 폐지 이어 '작은 정부론',4046,머니투데이,부정,0.99560546875
#
# 3,김부선 '가운뎃손가락' 들고 "이재명씨 쪽팔리지 않으세요?",4002,아이뉴스24,부정,0.9970703125
#
# 4,국민의힘 32% 4년9개월 만에 민주당 추월..국정농단 후 최고,3765,뉴스1,부정,0.9755859375
#
# 5,한일관계 개선 위해 도쿄 가려는 文.."성과없으면 역풍"고민,3635,중앙일보,부정,0.98779296875
#
# 6,조두순보다 더한 놈이 온다..'소녀 11명 성폭행' 김근식 9월 출소,3188,머니투데이,부정,0.99609375
#
# 7,"아무도 못오는 결혼식 됐다"..예비 부부들 '4단계 격상' 울분,3090,뉴스1,부정,0.99365234375
#
# 8,[단독][윤석열 인터뷰]⑤ "장모 일은 장모 일 내 길과 달라".."집사람 새벽까지 공부하며 바빠",2317,경향신문,부정,0.787109375
#
# 9,"오세훈의 세월호 지우기"..광화문 '기억공간' 철거 통보,2077,한겨레,부정,0.99169921875
#
# 10,日대사에 '90도 인사' 안한 이준석.."의식적으로 안 숙였다",1613,머니투데이,부정,0.984375
#
# 11,[단독][윤석열 인터뷰]④ '윤석열 사단'이 '하나회'처럼 군림 한다고요.."추 장관이 검찰에 대해 뭘 압니까",1530,경향신문,부정,0.99365234375
#
# 12,[현장연결] 유은혜 "서울·경기·인천 유초중고 14∼25일 전면 원격수업",1324,연합뉴스TV,중립,0.9599609375
#
# 13,이재명 '대세론 굳히기' 실패.. 이낙연 국민면접으로 '반등 기회',1238,문화일보,부정,0.9365234375
#
# 14,日스가 참을수 없는 동문서답.."코로나 책임질거냐" 묻자 "백신을",1218,서울신문,부정,0.94677734375
#
# 15,수도권 거리두기 4단계 격상..12일부터 2주간,1156,YTN,중립,0.84521484375
#
# 16,검찰 "정진웅 피해자 고통 호소를 오버액션으로 치부" 징역 1년 구형(종합),1148,뉴스1,부정,0.9921875
#
# 17,여신도 길들이기 성폭력 30대 목사 징역 7년..법정구속(종합),1092,연합뉴스,부정,0.9931640625
#
# 18,강남 뒤흔든 '코로나 패닉'.."이웃끼리 인사도 안해요",1073,뉴시스,부정,0.99755859375
#
# 19,"차라리 전국 셧다운해야"..존페 위기 카페업계 '울분',1035,뉴시스,부정,0.9970703125
#
# 20,김기현 "문대통령 수사대상 박영수에 면직선물..은혜 갚나",1015,연합뉴스,부정,0.98388671875
#
# 21,'독직폭행 혐의' 정진웅 실형 구형.."한동훈이 자초해"(종합),854,뉴시스,부정,0.990234375
#
# 22,與 "윤로남불" 尹 "결혼 전 일"..대선 전초전 '김건희 논문',740,중앙일보,부정,0.86083984375
#
# 23,'전국 최다 확진' 서울시.."오세훈 시장 대책에 역학조사 강화는 없어",737,한국일보,부정,0.984375
#
# 24,"강남에선 3시간 줄서야" 검사대란에..오세훈 "불편 줄일 앱 개발 지시",734,뉴시스,부정,0.96923828125
#
# 25,김의겸 "김건희 논문 9000만원짜리 관상 앱 사업계획서 갖다 쓴 것",690,한국일보,부정,0.8701171875
#
# 26,외신 한국 거리두기 격상 긴급 보도.."방역 모범국의 후퇴",658,뉴스1,부정,0.99560546875
#
# 27,[사진 톡톡] 인도네시아 코로나 사망자 폭증에..,617,연합뉴스,부정,0.9873046875
#
# 28,"이재명 '아웃사이더' 이낙연 '文후계자' 윤석열 '野 기수'",611,뉴스1,부정,0.5458984375
#
# 29,성일종 "김건희씨 논문 의혹? 본인이 공직 출마할 것도 아닌데..",586,이데일리,부정,0.98876953125
#
# 30,윤석열 "조국 의혹 쏟아질 때 대통령 임명장 잉크 만지며 고민",501,서울신문,부정,0.8271484375
#
# 31,靑 "성과 없이 안 간다"..'文 올림픽 조건부 참석' 고수,493,뉴시스,부정,0.99609375
#
# 32,"현대百만 하루 8830건"..확진자 폭증에 선별검사소 '번아웃',464,뉴스1,부정,0.994140625
#
# 33,"셧다운 전에 '벙개' 쳤어요".. 다닥다닥 '서울의 밤',459,문화일보,부정,0.99658203125
#
# 34,[뉴시스Pic] '가족들만 참석한 고(故) 박원순 전 시장 1주기 추모제',452,뉴시스,부정,0.67236328125
#
# 35,마지막 방역카드까지 썼다..1주 뒤 효과 안나오면 결국 '백신',407,머니투데이,부정,0.97705078125
#
# 36,[단독] 윤석열 '경찰 사칭' 방송국 기자 고발 검토,405,쿠키뉴스,부정,0.96337890625
#
# 37,윤석열 부인 논문 의혹에 거리 두는 국민의힘 "우린 대변인 아냐",366,오마이뉴스,부정,0.9970703125
#
# 38,'노출방송 거부' 여직원 무참히 살해한 BJ 항소심서 감형 왜?,349,머니투데이,부정,0.99755859375
#
# 39,김기현 文 향해 "코로나 방역 아마추어..'문데믹' 수렁에 빠져",293,아시아경제,부정,0.9951171875
#
# 40,서울경찰청 윤석열 부인 사문서위조 고발 사건 수사,274,연합뉴스,부정,0.8125
#
# 41,기초단체장들 "재난지원금 선별없이 전 국민에 전액 국비로 지급해야",264,뉴시스,부정,0.97705078125
#
# 42,[Q&A] '18시 이후 2인만' 제사·상견례도 예외없어..골프는 이번에도 캐디 '제외',217,뉴시스,중립,0.6708984375
#
# 43,[Q&A] 4명 카페갔다 오후 6시 넘으면?.."규정위반 개인과태료 10만원",213,연합뉴스,중립,0.6708984375
#
# 44,최재형에 줄잇는 조문..유승민 "형과 서로 아끼는 사이",211,연합뉴스,부정,0.71435546875
#
# 45,국민의힘 '비호감' 49%..원내 주요 5개 정당 중 가장 낮아,165,한국일보,부정,0.98291015625
#
# 46,故 박원순 1주기 눈물 흘린 강난희씨..지지자들은 "사모님 힘내세요",152,머니투데이,긍정,0.95166015625
#
# 47,윤석열 조국 저격? "文정부 실정은 민정수석실 실패에",148,파이낸셜뉴스,부정,0.99609375
#
# 48,'親정부 보도로 사퇴' 정연주 전 KBS사장 방심위원장 강행 수순,137,문화일보,부정,0.99267578125
#
# 49,이동학 尹아내 논문 의혹에 "양심의 문제 영부인 의미 되새겨야",126,머니투데이,부정,0.9853515625
#
# 50,'이재명 제주 오지 말라'던 원희룡 여권 대선주자 정세균엔?,109,연합뉴스,부정,0.97021484375

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# https://news.daum.net/ranking/bestreply

# %% [markdown]
# ---
#
#
# ※ 카카오톡 메신저 내용 분석해보기
#
#
# ---
